# %% [markdown]
# I copied and pasted the list of fixtures from: https://draft.premierleague.com/league into a spreadsheet program and downloaded it as a csv. I will now clean the data and add it as a table in ym database

# %%
import pandas as pd

# %%
df = pd.read_csv('fixtures - Sheet1.csv')

# %%
df
# Out:
#                                 player_1 scores  \
# 0                            Gameweek 30    NaN
# 1         All the Smallings\nShane Smith  0 - 0
# 2       Stop Crying Lampard\nDylan Payne  0 - 0
# 3    Neuer Gonna Give You\nCiaran Lebrun  0 - 0
# 4                            Gameweek 29    NaN
# ..                                   ...    ...
# 147       All the Smallings\nShane Smith      v
# 148                          Gameweek 38    NaN
# 149  Neuer Gonna Give You\nCiaran Lebrun      v
# 150      Obi-Wan Iwobi\nMatthew Farrelly      v
# 151     Ducks of Bethlehem\nDaragh Payne      v
#
#                              player_2
# 0                                 NaN
# 1       Childish Gbaminos\nBen McCabe
# 2    Ducks of Bethlehem\nDaragh Payne
# 3     Obi-Wan Iwobi\nMatthew Farrelly
# 4                                 NaN
# ..                                ...
# 147  Stop Crying Lampard\nDylan Payne
# 148                               NaN
# 149     Childish Gbaminos\nBen McCabe
# 150  Stop Crying Lampard\nDylan Payne
# 151    All the Smallings\nShane Smith
#
# [152 rows x 3 columns]

# %% [markdown]
# the patern seems to be a string indicating the gameweek followed by threee fixtures. I will parse the gameweek from the string and create a list with the gameweek for each row

# %%
gameweek = []
indexes = []

for i in range(len(df)):
    print(df['player_1'].iloc[i].split()[0])
    li = df['player_1'].iloc[i].split()
    if li[0] == 'Gameweek':
        # appending the index of the rows with the gameweek string to drop them
        indexes.append(i)
        for i in range(3):
            gameweek.append(li[1])
            print(li[1])
# Out:
# Gameweek
# 30
# the
# Crying
# All
# Stop
# Neuer
# Gameweek
# 30
# the
# Crying
# Childish
# All
# Stop
# Gameweek
# 30
# the
# Crying
# Neuer
# Obi-Wan
# Ducks
# Gameweek
# 30
# the
# Crying
# Childish
# Ducks
# All
# Gameweek
# 30
# the
# Crying
# Stop
# Neuer
# Obi-Wan
# Gameweek
# 30
# the
# Crying
# All
# Stop
# Neuer
# Gameweek
# 30
# the
# Crying
# Childish
# All
# Stop
# Gameweek
# 30
# the
# Crying
# Neuer
# Obi-Wan
# Ducks
# Gameweek
# 30
# the
# Crying
# Childish
# Ducks
# All
# Gameweek
# 30
# the
# Crying
# Stop
# Neuer
# Obi-Wan
# Gameweek
# 30
# the
# Crying
# All
# Stop
# Neuer
# Gameweek
# 30
# the
# Crying
# Childish
# All
# Stop
# Gameweek
# 30
# the
# Crying
# Neuer
# Obi-Wan
# Ducks
# Gameweek
# 30
# the
# Crying
# Childish
# Ducks
# All
# Gameweek
# 30
# the
# Crying
# Stop
# Neuer
# Obi-Wan
# Gameweek
# 30
# the
# Crying
# All
# Stop
# Neuer
# Gameweek
# 30
# the
# Crying
# Childish
# All
# Stop
# Gameweek
# 30
# the
# Crying
# Neuer
# Obi-Wan
# Ducks
# Gameweek
# 30
# the
# Crying
# Childish
# Ducks
# All
# Gameweek
# 30
# the
# Crying
# Stop
# Neuer
# Obi-Wan
# Gameweek
# 30
# the
# Crying
# All
# Stop
# Neuer
# Gameweek
# 30
# the
# Crying
# Childish
# All
# Stop
# Gameweek
# 30
# the
# Crying
# Neuer
# Obi-Wan
# Ducks
# Gameweek
# 30
# the
# Crying
# Childish
# Ducks
# All
# Gameweek
# 30
# the
# Crying
# Stop
# Neuer
# Obi-Wan
# Gameweek
# 30
# the
# Crying
# All
# Stop
# Neuer
# Gameweek
# 30
# the
# Crying
# Childish
# All
# Stop
# Gameweek
# 30
# the
# Crying
# Neuer
# Obi-Wan
# Ducks
# Gameweek
# 30
# the
# Crying
# Childish
# Ducks
# All
# Gameweek
# 30
# the
# Crying
# Stop
# Neuer
# Obi-Wan
# Gameweek
# 30
# the
# Crying
# Stop
# Neuer
# Obi-Wan
# Gameweek
# 30
# the
# Crying
# Childish
# Ducks
# All
# Gameweek
# 30
# the
# Crying
# Neuer
# Obi-Wan
# Ducks
# Gameweek
# 30
# the
# Crying
# Childish
# All
# Stop
# Gameweek
# 30
# the
# Crying
# All
# Stop
# Neuer
# Gameweek
# 30
# the
# Crying
# Stop
# Neuer
# Obi-Wan
# Gameweek
# 30
# the
# Crying
# Childish
# Ducks
# All
# Gameweek
# 30
# the
# Crying
# Neuer
# Obi-Wan
# Ducks

# %%
gameweek
# Out:
# ['30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying',
#  '30',
#  'the',
#  'Crying']
